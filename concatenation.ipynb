# %% [markdown]
# ## Using pandas for the different csv concatenation

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - Reading the data

# %%
csvs = []
csvs.append(pd.read_csv('franklin_audio_features.csv'))
csvs.append(pd.read_csv('mateo_audio_features.csv'))
csvs.append(pd.read_csv('santiago_audio_features.csv'))
csvs.append(pd.read_csv('sebastian_audio_features.csv'))
csvs.append(pd.read_csv('isabella_audio_features.csv'))

# %% [markdown]
# - Showing the data

# %%
final_data = pd.concat([x for x in csvs])
final_data
# Out:
#                                                     name       rms       zcr  \
# 0                         Michael Nyman - Little Impulse  0.065964  0.046735
# 1                                 Marjolaine - Les seins  0.195174  0.062496
# 2                       Com.A - Hallucination Acid Lobot  0.152191  0.092273
# 3      Gorillaz, Little Dragon - To Binge (feat. Litt...  0.217958  0.057644
# 4      John McLaughlin - Very Early (Homage to Bill E...  0.049399  0.023015
# ...                                                  ...       ...       ...
# 10631               Cécile Corbel - The Neglected Garden  0.109971  0.047063
# 10632           Red Hot Chili Peppers - Whatever We Want  0.296770  0.069377
# 10633     Black Rebel Motorcycle Club - Spread Your Love  0.324813  0.044874
# 10634                              Scrog - Eerie Invited  0.184346  0.054730
# 10635  Frédéric Chopin, Milosz Magin - Berceuse in D-...  0.039687  0.024706
#
# ...

# %%
final_data.shape
# Out:
# (45406, 25)

# %%
final_data = final_data.sort_values("name")
final_data
# Out:
#                                                    name       rms       zcr  \
# 7864                            !!! - Pardon My Freedom  0.256879  0.074434
# 6086                          !!! - Wannagain Wannagain  0.282032  0.085831
# 3958  !!! - When the Going Gets Tough, the Tough Get...  0.193642  0.075629
# 9026                            #1 Dads - Life, Oh Life  0.168422  0.026437
# 8961                     'Til Tuesday - Coming Up Close  0.071269  0.056542
# ...                                                 ...       ...       ...
# 6225                             茅原実里 - sleeping terror  0.246367  0.071125
# 1193              龚琳娜 - The Rooster Calls from the East  0.137976  0.069065
# 6711               아침 Achime - Rainbow at 02 AM 02시 무지개  0.275941  0.084372
# 4041                                          ２８１４ - 恢复  0.139856  0.027137
# 6203                                                NaN       NaN       NaN
#
# ...

# %%
final_data  = final_data.dropna()
final_data
# Out:
#                                                    name       rms       zcr  \
# 7864                            !!! - Pardon My Freedom  0.256879  0.074434
# 6086                          !!! - Wannagain Wannagain  0.282032  0.085831
# 3958  !!! - When the Going Gets Tough, the Tough Get...  0.193642  0.075629
# 9026                            #1 Dads - Life, Oh Life  0.168422  0.026437
# 8961                     'Til Tuesday - Coming Up Close  0.071269  0.056542
# ...                                                 ...       ...       ...
# 3690                                茅原実里 - PRECIOUS ONE  0.213880  0.066889
# 6225                             茅原実里 - sleeping terror  0.246367  0.071125
# 1193              龚琳娜 - The Rooster Calls from the East  0.137976  0.069065
# 6711               아침 Achime - Rainbow at 02 AM 02시 무지개  0.275941  0.084372
# 4041                                          ２８１４ - 恢复  0.139856  0.027137
#
# ...

# %%
final_data = final_data.reset_index().drop("index", axis=1)
final_data
# Out:
#                                                     name       rms       zcr  \
# 0                                !!! - Pardon My Freedom  0.256879  0.074434
# 1                              !!! - Wannagain Wannagain  0.282032  0.085831
# 2      !!! - When the Going Gets Tough, the Tough Get...  0.193642  0.075629
# 3                                #1 Dads - Life, Oh Life  0.168422  0.026437
# 4                         'Til Tuesday - Coming Up Close  0.071269  0.056542
# ...                                                  ...       ...       ...
# 45400                                茅原実里 - PRECIOUS ONE  0.213880  0.066889
# 45401                             茅原実里 - sleeping terror  0.246367  0.071125
# 45402              龚琳娜 - The Rooster Calls from the East  0.137976  0.069065
# 45403               아침 Achime - Rainbow at 02 AM 02시 무지개  0.275941  0.084372
# 45404                                          ２８１４ - 恢复  0.139856  0.027137
#
# ...

# %%
final_data.to_csv("audio_features.csv")

# %%
tempo = final_data["tempo"].loc[1]
tempo
# Out:
# '[122.2826087]'

# %%
if tempo[0] == '[':
    tempo = float(tempo.strip('[]'))
tempo
# Out:
# 122.2826087
